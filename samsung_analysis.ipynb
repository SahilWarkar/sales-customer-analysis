# %%
import pandas as pd
df = pd.read_csv("samsung_sales_dataset.csv")

df.head(20)
df.describe
# Out:
# <bound method DataFrame.info of             Order_ID  Order_Date Product_Category         Product_Name  \
# 0      SM-2022136947  12-11-2023       Smartphone       Galaxy Z Flip6
# 1      SM-2022128383  28-03-2024       Smartphone     Galaxy S23 Ultra
# 2      SM-2022166034  26-02-2024       Smartphone           Galaxy S25
# 3      SM-2022091358  13-12-2025       Smartphone           Galaxy A34
# 4      SM-2022102732  18-12-2022         Wearable        Galaxy Watch5
# ...              ...         ...              ...                  ...
# 59995  SM-2022114423  08-07-2026           Tablet  Galaxy Tab S9 Ultra
# 59996  SM-2022140838  18-06-2024       Smartphone     Galaxy S22 Ultra
# 59997  SM-2022092217  10-12-2024               TV         OLED S95 65"
# 59998  SM-2022175325  08-04-2023       Smartphone           Galaxy S25
# 59999  SM-2022010406  05-12-2024       Smartphone           Galaxy A55
#
#        Unit_Price_USD  Quantity  Discount_Percent  Gross_Amount_USD  \
# ...
